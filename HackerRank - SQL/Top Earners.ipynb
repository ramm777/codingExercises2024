# %% [markdown]
# ![image.png](attachment:image.png)

# %%
SELECT MAX(salary*months), COUNT(salary*months) 
FROM Employee
WHERE salary*months = (SELECT MAX(salary*months) FROM Employee);

# %% [markdown]
# - I don't fully understand how WHERE is used here?
