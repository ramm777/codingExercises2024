# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Poorly written. You need to write, When a manager leaves the company, their id is deleted from employee_id, but is kept in manager_id

# %% [markdown]
# SELECT employee_id
# FROM Employees
# WHERE salary < 30000
#       AND manager_id NOT IN (SELECT employee_id FROM Employees WHERE employee_id IS NOT NULL)
# ORDER BY employee_id;
