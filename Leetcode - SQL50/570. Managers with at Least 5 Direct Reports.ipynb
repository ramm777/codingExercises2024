# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# -- Notcie using "IN", not "=" as there could be more than 1 managerId-s
# SELECT name
# FROM Employee
# WHERE Employee.id IN
#         (SELECT managerId
#         FROM Employee
#         WHERE managerId IS NOT NULL
#         GROUP BY managerId
#         HAVING COUNT(managerId) >= 5);
