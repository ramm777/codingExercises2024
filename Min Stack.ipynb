# %% [markdown]
# ![2024_07_24_14_11_01_Explore_LeetCode.png](attachment:2024_07_24_14_11_01_Explore_LeetCode.png)

# %% [markdown]
# - The idea is to record (to a list) a minimum value of a stack at each push, as you push in any case.
# - When you pop stack you need to pop min_stack. pop() defaults popping from pop(-1) RHS.
# - Stack's bottom is left, top is right in a list

# %%
class MinStack:
    # Stack's bottom is left, top is right
    def __init__(self):
        self.stack = []
        self.min_stack = []

    def push(self, val: int) -> None:
        self.stack.append(val)  
        
        # Check if min_stack is empty or the current value is less than or equal to the top of min_stack
        if self.min_stack == [] or val <= self.min_stack[-1]:
            self.min_stack.append(val)
        else:
            self.min_stack.append(self.min_stack[-1])          

    def pop(self) -> None:
        if self.stack:
            item = self.stack[-1]
            del self.stack[-1]
            del self.min_stack[-1]
            return item

    def top(self) -> int:
        if self.stack:
            return self.stack[-1]

    def getMin(self) -> int:
        if self.min_stack: 
            return self.min_stack[-1]


minStack = MinStack()
minStack.push(-2)
minStack.push(0)
minStack.push(-3)
print(minStack.getMin()) # return -3
minStack.pop() 
print(minStack.top())    # return 0
print(minStack.getMin()) # return -2
# Out:
# -3
# 0
# -2
