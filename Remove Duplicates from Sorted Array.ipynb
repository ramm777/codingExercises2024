# %% [markdown]
# ![2024-07-16 11_30_00-.png](<attachment:2024-07-16 11_30_00-.png>)

# %%
#nums = [0,0,1,1,1,2,2,3,3,4]
#nums = [1,1,2]
nums = [1,1,1,3,4,5,5,5,5,7,7,7,9,9,18]

# %%
for i in range(len(nums)-1, 0, -1):
    if nums[i] == nums[i-1]:
        del nums[i] 

nums
# Out:
# [0, 1, 2, 3, 4]

# %% [markdown]
# #### Remember to delete list items only from the last one in reverse order. Otgherwise the logic in "if" is not gonna work if you modify it in from the beginning, you are modifying the list itself!!!
