# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![2024-07-15 18_02_59-LeetCode #1_ Two Sum _ Coding Interview Solution - YouTube.png](<attachment:2024-07-15 18_02_59-LeetCode #1_ Two Sum _ Coding Interview Solution - YouTube.png>)

# %% [markdown]
# if 10 (target) - 6 (i) is present in previously seen_list (keys), then these two are the solution.

# %%
nums = [7,3,2,4] 
target = 6
nums
# Out:
# [7, 3, 2, 4]

# %%
# Brute force O(n^2) - two loops
for i in range(len(nums)):
    for j in range(i+1, len(nums)): 
        if nums[i] + nums[j] == target:
            print([i,j])
# Out:
# [2, 3]

# %%
# O(nlog(n)) - one loop, seen(num:index)

def TwoSum(nums, target): 
    seen = {}
    for i in range(len(nums)):
        
        diff = target - nums[i]
        if diff in seen.keys(): 
            return [seen[diff], i]
        else: 
            seen[nums[i]] = i
            
TwoSum(nums, target)
# Out:
# [2, 3]

# %%
# If you record diff and seen before comparison, then the current num will be compared with itself
# This is also a question in interview. Think more about this situation.  

seen = {}
for i in range(len(nums)):
    
    diff = target - nums[i]
    seen[nums[i]] = i
    
    if diff in seen.keys(): 
        print([seen[diff], i])
        break

seen
# Out:
# [1, 1]
# {7: 0, 3: 1}
